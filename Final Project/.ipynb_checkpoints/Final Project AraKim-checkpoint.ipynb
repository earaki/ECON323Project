# %% [markdown]
# ## Predicting GDP/GNP Growth With Football-related Metrics

# %% [markdown]
# *by: Emiko Araki and Sean Kim*

# %% [markdown]
# ## Primary Research Question
#
# To what extent can football-related metrics (e.g. FIFA rankings, tournament participation, football infrastructure in a country) predict year-over-year GDP and GNP growth across countries where football is the biggest sport?
#
# ***Method:***
#
# **Step 1: Defining Footballing Countries**
#
# - First we define countries where football is culturally significant
#
# **Step 2: Data Collection**
#
# - Football Metrics
# - Economic Metrics
#
# **Step 3: Creating a Dataset (done in between loading data)**
#
# - Cleaning and merging data into one dataset with the economic metric as target variables and football metrics are features.
#
# **Step 4: Predictive Analysis**
#
# - Regression model to predict GDP/GNP
#
# **Step 5: Analysis**
#
# - Can football-related metrics be significant predictors of GDP growth?
# - Random Forest can help find important features with its criterion hyperparameter
#
# **Step 6: Findings**
#
# - Key takeaways"
# - Findings for future research

# %% [markdown]
# ## Step 1: Defining football
#
# In the first step of our project, we find the top 10 countries where football is the most popular sport.
#
# The reason why we want to make sure football is the most popular sport is because this way it is more likely to make an impact. Countries where football is the most dominant sport, its economic and cultural significance is larger. Therefore, football is more likely to impact GDP/GNI. Further research could look at how other sports (e.g. US and american football, India and cricket, etc.) impact economic activity.
#
# To find these countries, we build upon research done by [Ticketgum](https://www.ticketgum.com/blog/most-football-crazy-countries). In order to find the countries that are the craziest about football, Ticketgum performed research on 42 countries on variables including:
#
# - Number of football stadiums and their capacities
# - Match attendance rates
# - Total market value
# - Interest in the World Cup
# - Domestic broadcast deal values
#
# Ticketgum took these variables and used a weighted average to create an index for the 42 countries. Here are the rankings that Ticketgum found:
#
# 1. England (8.37 out of 10)
# 2. Spain (7.83 out of 10)
# 3. Germany (7.83 out of 10)
# 4. Brazil (7.60 out of 10)
# 5. Italy  (7.52 out of 10)
# 6. Argentina (7.17 out of 10)
# 7. Mexico (6.71 out of 10)
# 8. United States (6.71 out of 10)
# 9. France (6.63 out of 10)
# 10. Saudi Arabia (5.74 out of 10)
# 11. Turkey (5.70 out of 10)
# 12. Qatar (5.43 out of 10)
# 13. South Korea (5.23 out of 10)
# 14. Indonesia (5.23 out of 10)
# 15. Colombia (5.39 out of 10)
# 16. Portugal (5.19 out of 10)
# 17. The Netherlands (4.65 out of 10)
# 18. Poland (4.54 out of 10)
# 19. Scotland (3.84 out of 10)
# 20. Switzerland (3.30 out of 10)
#
# We decided to use the findings of this study as the metric for the countries where football is the most popular sport because of the criteria.
#
# We wanted to make sure that the criteria used to find the countries did not overlap with the criteria we were going to use for the following analysis.

# %% [markdown]
# ## Step 2: Data Collection
#
# **Football Metrics**
#
# For football metrics, we break it down into 4 aspects:
# 1. Performance-Based Metrics
# 2. Participation and Development Metrics
# 3. Player Development Metrics
# 4. Socioeconomic Impact Metrics
# 5. International Engagement Metrics
#
# **Performance-Based Metrics**
#
# These metrics will capture the success of a country's team on the international stage.
# 1. FIFA Rankings
# 2. Number of professional players playing in Europe's top leagues
# 3. We find the total market value of the number one league and average market value of players in each country.

# %%
# !pip install pandas
import pandas as pd
# Out:
# WARNING: Skipping /opt/conda/lib/python3.11/site-packages/nlopt-2.7.1.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /opt/conda/lib/python3.11/site-packages/nlopt-2.7.1.dist-info due to invalid metadata entry 'name'
# Requirement already satisfied: pandas in /opt/conda/lib/python3.11/site-packages (2.2.2)
# Requirement already satisfied: numpy>=1.23.2 in /opt/conda/lib/python3.11/site-packages (from pandas) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/conda/lib/python3.11/site-packages (from pandas) (2.9.0)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/lib/python3.11/site-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /opt/conda/lib/python3.11/site-packages (from pandas) (2024.1)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# WARNING: Skipping /opt/conda/lib/python3.11/site-packages/nlopt-2.7.1.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /opt/conda/lib/python3.11/site-packages/nlopt-2.7.1.dist-info due to invalid metadata entry 'name'

# %%
#Loading data for FIFA Rankings over 20 years (2003 - 2023)  

# 2023
fifa_ranking_2023 = pd.read_csv('Data sets/Fifa Rankings (2010-2024)/FIFA Ranking 2023.csv')
fifa_ranking_2023['Team'] = fifa_ranking_2023['Team'].str.replace(r'[A-Z]{3}\s*https.*', '', regex=True)
fifa_ranking_2023 = fifa_ranking_2023.drop(columns=['+/-', 'Match window', 'More'])

# 2022
fifa_ranking_2022 = pd.read_csv('Data sets/Fifa Rankings (2010-2024)/FIFA Ranking 2022.csv')
fifa_ranking_2022['Team'] = fifa_ranking_2022['Team'].str.replace(r'[A-Z]{3}\s*https.*', '', regex=True)
fifa_ranking_2022 = fifa_ranking_2022.drop(columns=['+/-', 'Match window', 'More'])

# 2021
fifa_ranking_2021 = pd.read_csv('Data sets/Fifa Rankings (2010-2024)/FIFA Ranking 2021.csv')
fifa_ranking_2021['Team'] = fifa_ranking_2021['Team'].str.replace(r'[A-Z]{3}\s*https.*', '', regex=True)
fifa_ranking_2021 = fifa_ranking_2021.drop(columns=['+/-', 'Match window', 'More'])

# 2020
fifa_ranking_2020 = pd.read_csv('Data sets/Fifa Rankings (2010-2024)/FIFA Ranking 2020.csv')
fifa_ranking_2020['Team'] = fifa_ranking_2020['Team'].str.replace(r'[A-Z]{3}\s*https.*', '', regex=True)
fifa_ranking_2020 = fifa_ranking_2020.drop(columns=['+/-', 'Match window', 'More'])

# 2019
fifa_ranking_2019 = pd.read_csv('Data sets/Fifa Rankings (2010-2024)/FIFA Ranking 2019.csv')
fifa_ranking_2019['Team'] = fifa_ranking_2019['Team'].str.replace(r'[A-Z]{3}\s*https.*', '', regex=True)
fifa_ranking_2019 = fifa_ranking_2019.drop(columns=['+/-', 'Match window', 'More'])

# 2018
fifa_ranking_2018 = pd.read_csv('Data sets/Fifa Rankings (2010-2024)/FIFA Ranking 2018.csv')
fifa_ranking_2018['Team'] = fifa_ranking_2018['Team'].str.replace(r'[A-Z]{3}\s*https.*', '', regex=True)
fifa_ranking_2018 = fifa_ranking_2018.drop(columns=['+/-', 'More'])

# 2017
fifa_ranking_2017 = pd.read_csv('Data sets/Fifa Rankings (2010-2024)/FIFA Ranking 2017.csv')
fifa_ranking_2017['Team'] = fifa_ranking_2017['Team'].str.replace(r'[A-Z]{3}\s*https.*', '', regex=True)
fifa_ranking_2017 = fifa_ranking_2017.drop(columns=['+/-', 'More'])

# 2016
fifa_ranking_2016 = pd.read_csv('Data sets/Fifa Rankings (2010-2024)/FIFA Ranking 2016.csv')
fifa_ranking_2016['Team'] = fifa_ranking_2016['Team'].str.replace(r'[A-Z]{3}\s*https.*', '', regex=True)
fifa_ranking_2016 = fifa_ranking_2016.drop(columns=['+/-', 'More'])

# 2015
fifa_ranking_2015 = pd.read_csv('Data sets/Fifa Rankings (2010-2024)/FIFA Ranking 2015.csv')
fifa_ranking_2015['Team'] = fifa_ranking_2015['Team'].str.replace(r'[A-Z]{3}\s*https.*', '', regex=True)
fifa_ranking_2015 = fifa_ranking_2015.drop(columns=['+/-', 'More'])

# 2014
fifa_ranking_2014 = pd.read_csv('Data sets/Fifa Rankings (2010-2024)/FIFA Ranking 2014.csv')
fifa_ranking_2014['Team'] = fifa_ranking_2014['Team'].str.replace(r'[A-Z]{3}\s*https.*', '', regex=True)
fifa_ranking_2014 = fifa_ranking_2014.drop(columns=['+/-', 'More'])

# 2013
fifa_ranking_2013 = pd.read_csv('Data sets/Fifa Rankings (2010-2024)/FIFA Ranking 2013.csv')
fifa_ranking_2013['Team'] = fifa_ranking_2013['Team'].str.replace(r'[A-Z]{3}\s*https.*', '', regex=True)
fifa_ranking_2013 = fifa_ranking_2013.drop(columns=['+/-', 'More'])

# 2012
fifa_ranking_2012 = pd.read_csv('Data sets/Fifa Rankings (2010-2024)/FIFA Ranking 2012.csv')
fifa_ranking_2012['Team'] = fifa_ranking_2012['Team'].str.replace(r'[A-Z]{3}\s*https.*', '', regex=True)
fifa_ranking_2012 = fifa_ranking_2012.drop(columns=['+/-', 'More'])

# 2011
fifa_ranking_2011 = pd.read_csv('Data sets/Fifa Rankings (2010-2024)/FIFA Ranking 2011.csv')
fifa_ranking_2011['Team'] = fifa_ranking_2011['Team'].str.replace(r'[A-Z]{3}\s*https.*', '', regex=True)
fifa_ranking_2011 = fifa_ranking_2011.drop(columns=['+/-', 'More'])

# 2010
fifa_ranking_2010 = pd.read_csv('Data sets/Fifa Rankings (2010-2024)/FIFA Ranking 2010.csv')
fifa_ranking_2010['Team'] = fifa_ranking_2010['Team'].str.replace(r'[A-Z]{3}\s*https.*', '', regex=True)
fifa_ranking_2010 = fifa_ranking_2010.drop(columns=['+/-', 'More'])

# 2009
fifa_ranking_2009 = pd.read_csv('Data sets/Fifa Rankings (2010-2024)/FIFA Ranking 2009.csv')
fifa_ranking_2009['Team'] = fifa_ranking_2009['Team'].str.replace(r'[A-Z]{3}\s*https.*', '', regex=True)
fifa_ranking_2009 = fifa_ranking_2009.drop(columns=['+/-', 'More'])

# 2008
fifa_ranking_2008 = pd.read_csv('Data sets/Fifa Rankings (2010-2024)/FIFA Ranking 2008.csv')
fifa_ranking_2008['Team'] = fifa_ranking_2008['Team'].str.replace(r'[A-Z]{3}\s*https.*', '', regex=True)
fifa_ranking_2008 = fifa_ranking_2008.drop(columns=['+/-', 'More'])

# 2007
fifa_ranking_2007 = pd.read_csv('Data sets/Fifa Rankings (2010-2024)/FIFA Ranking 2007.csv')
fifa_ranking_2007['Team'] = fifa_ranking_2007['Team'].str.replace(r'[A-Z]{3}\s*https.*', '', regex=True)
fifa_ranking_2007 = fifa_ranking_2007.drop(columns=['+/-', 'More'])

# 2006
fifa_ranking_2006 = pd.read_csv('Data sets/Fifa Rankings (2010-2024)/FIFA Ranking 2006.csv')
fifa_ranking_2006['Team'] = fifa_ranking_2006['Team'].str.replace(r'[A-Z]{3}\s*https.*', '', regex=True)
fifa_ranking_2006 = fifa_ranking_2006.drop(columns=['+/-', 'More'])

# 2005
fifa_ranking_2005 = pd.read_csv('Data sets/Fifa Rankings (2010-2024)/FIFA Ranking 2005.csv')
fifa_ranking_2005['Team'] = fifa_ranking_2005['Team'].str.replace(r'[A-Z]{3}\s*https.*', '', regex=True)
fifa_ranking_2005 = fifa_ranking_2005.drop(columns=['+/-', 'More'])

# 2004
fifa_ranking_2004 = pd.read_csv('Data sets/Fifa Rankings (2010-2024)/FIFA Ranking 2004.csv')
fifa_ranking_2004['Team'] = fifa_ranking_2004['Team'].str.replace(r'[A-Z]{3}\s*https.*', '', regex=True)
fifa_ranking_2004 = fifa_ranking_2004.drop(columns=['+/-', 'More'])

# 2003
fifa_ranking_2003 = pd.read_csv('Data sets/Fifa Rankings (2010-2024)/FIFA Ranking 2003.csv')
fifa_ranking_2003['Team'] = fifa_ranking_2003['Team'].str.replace(r'[A-Z]{3}\s*https.*', '', regex=True)
fifa_ranking_2003 = fifa_ranking_2003.drop(columns=['+/-', 'More'])

# %%
# Load and merge 2023 rankings separately
fifa_ranking_2023 = pd.read_csv('Data sets/Fifa Rankings (2010-2024)/FIFA Ranking 2023 Cleaned.csv')
fifa_ranking_2023
# Out:
#       RK                                               Team  Total Points  \
# 0      1  ArgentinaARG https://api.fifa.com/api/v3/pictu...       1855.20
# 1      2  FranceFRA https://api.fifa.com/api/v3/picture/...       1845.44
# 2      3  EnglandENG https://api.fifa.com/api/v3/picture...       1800.05
# 3      4  BelgiumBEL https://api.fifa.com/api/v3/picture...       1798.46
# 4      5  BrazilBRA https://api.fifa.com/api/v3/picture/...       1784.09
# ..   ...                                                ...           ...
# 201  202  BahamasBAH https://api.fifa.com/api/v3/picture...        835.81
# 202  203  LiechtensteinLIE https://api.fifa.com/api/v3/p...        833.01
# 203  204  Sri LankaSRI https://api.fifa.com/api/v3/pictu...        822.03
# 204  205  GuamGUM https://api.fifa.com/api/v3/picture/fl...        821.91
# 205  206  Turks and Caicos IslandsTCA https://api.fifa.c...        818.57
#
#      Previous Points +/- Match window  More
# 0            1855.20   -          NaN   NaN
# 1            1845.44   -          NaN   NaN
# 2            1800.05   -          NaN   NaN
# 3            1798.46   -          NaN   NaN
# 4            1784.09   -          NaN   NaN
# ..               ...  ..          ...   ...
# 201           835.81   -          NaN   NaN
# 202           833.01   -          NaN   NaN
# 203           822.03   -          NaN   NaN
# 204           821.91   -          NaN   NaN
# 205           818.57   -          NaN   NaN
#
# [206 rows x 7 columns]

# %%
filtered_teams = [
    "England", "Spain", "Germany", "Brazil", "Italy", "Argentina", "Mexico",
    "USA", "France", "Saudi Arabia", "Turkey", "Qatar", "Korea Republic",
    "Indonesia", "Colombia", "Portugal", "Netherlands", "Poland", "Scotland",
    "Switzerland"
]

years = list(range(2003, 2023))

# Initialize an empty list to store the yearly DataFrames
dfs = []

# Loop through each year and read the corresponding cleaned FIFA ranking data
for year in years:
    file_path = f'Data sets/Fifa Rankings (2010-2024)/FIFA Ranking {year} Cleaned.csv'
    df = pd.read_csv(file_path)
    # Keep only the 'Team' and 'RK' columns
    df = df[['Team', 'RK']]
    # Filter by selected teams
    df = df[df['Team'].isin(filtered_teams)]
    # Rename the 'RK' column to indicate the year
    df = df.rename(columns={'RK': f'RK_{year}'})
    
    # Append the dataframe to the list
    dfs.append(df)

# Merge all DataFrames from the list
fifa_ranking_df = dfs[0]
for df in dfs[1:]:
    fifa_ranking_df = pd.merge(fifa_ranking_df, df, on='Team', how='outer')

# Clean up column names and adjust formatting
fifa_ranking_df.columns = fifa_ranking_df.columns.str.replace('RK_', '')
fifa_ranking_df = fifa_ranking_df.rename(columns={'Team': 'Country'})
fifa_ranking_df["Country"] = fifa_ranking_df["Country"].replace("USA", "United States")  #Making sure country names are the same
fifa_ranking_df["Country"] = fifa_ranking_df["Country"].replace("Korea Republic", "South Korea")
fifa_ranking_df
# Out:
#           Country  2003  2004  2005  2006  2007  2008  2009  2010  2011  ...  \
# 0       Argentina     5     3     4     3     1     6     8     5    10  ...
# 1          Brazil     1     1     1     1     2     5     2     4     6  ...
# 2        Colombia    39    26    24    34    17    49    39    48    36  ...
# 3         England     8     8     9     5    12     8     9     6     5  ...
# 4          France     2     2     5     4     7    11     7    18    15  ...
# 5         Germany    12    19    16     6     5     2     6     3     3  ...
# 6       Indonesia    91    91   109   153   133   139   120   127   142  ...
# 7           Italy    10    10    12     2     3     4     4    14     9  ...
# 8     South Korea    22    22    29    51    42    42    52    40    32  ...
# 9          Mexico     7     7     5    20    15    26    17    27    21  ...
# 10    Netherlands     4     6     3     7     9     3     3     2     2  ...
# 11         Poland    25    25    22    24    22    34    58    73    66  ...
# 12       Portugal    17     9    10     8     8    11     5     8     7  ...
# 13          Qatar    65    66    95    58    87    84    86   112    93  ...
# 14   Saudi Arabia    26    28    33    64    61    48    63    80    96  ...
# 15       Scotland    54    86    60    25    14    33    46    52    47  ...
# 16          Spain     3     5     5    12     4     1     1     1     1  ...
# 17    Switzerland    44    51    35    17    44    24    18    22    17  ...
# 18         Turkey     8    14    11    26    16    10    41    31    28  ...
# 19  United States    11    11     8    31    19    22    14    18    34  ...
#
#     2013  2014  2015  2016  2017  2018  2019  2020  2021   2022
# 0      3     2     2     1     4    11     9     7     5    2.0
# 1     10     6     6     2     2     3     3     3     2    1.0
# 2      4     3     8     6    13    12    10    15    16   17.0
# 3     13    13     9    13    15     5     4     4     4    5.0
# 4     20     7    25     7     9     2     2     2     3    3.0
# 5      2     1     4     3     1    16    15    13    12   14.0
# 6    161   159   179   171   162  1591   173   173   164  151.0
# 7      7    11    15    16    14    18    13    10     6    8.0
# 8     54    69    51    37    60    53    40    38    33   25.0
# 9     21    20    22    18    16    17    11     9    14   15.0
# 10     9     5    14    22    20    14    14    14    10    6.0
# 11    76    41    34    15     7    20    19    19    27   22.0
# 12     5     7     7     8     3     6     7     5     8    9.0
# 13   103    95    86    87   102    93    55    58    48   60.0
# 14    87   102    80    54    63    69    67    67    51   49.0
# 15    34    36    52    67    34    38    50    48    38   42.0
# 16     1     9     3    10     6     9     8     6     7   10.0
# 17     8    12    12    11     8     8    12    16    13   12.0
# 18    43    49    21    24    42    39    29    32    37    NaN
# 19    14    27    32    28    24    25    22    22    11   13.0
#
# [20 rows x 21 columns]

# %%
#List of countries to filter
filtered_teams = [
    "England", "Spain", "Germany", "Brazil", "Italy", "Argentina", "Mexico",
    "United States", "France", "Saudi Arabia", "Türkiye", "Qatar", "Korea Republic",
    "Indonesia", "Colombia", "Portugal", "Netherlands", "Poland", "Scotland",
    "Switzerland"]

#Load player data from multiple CSV files, filter by the given countries, and merge the results.
def load_and_filter_players_data(file_paths, filtered_teams):

    dfs = []
    
    for file_path in file_paths:
        df = pd.read_csv(file_path)
        df['Nation'] = df['Nation'].apply(lambda x: ' '.join(x.split()[1:]))
        if '# Players' in df.columns:
            df = df[df['Nation'].isin(filtered_teams)]
            year = file_path.split('/')[-1].split('-')[0]
            df = df[['Nation', '# Players']]
            df = df.rename(columns={'# Players': f'{year}'})
            dfs.append(df)

    if dfs:
        merged_df = dfs[0]
        for df in dfs[1:]:
            merged_df = pd.merge(merged_df, df, on='Nation', how='outer')

        merged_df.set_index('Nation', inplace=True)
        return merged_df
    else:
        print("No dataframes to merge.")
        return pd.DataFrame()

# Example usage with the uploaded files
file_paths = ["Data sets/NumberPlayers/2003-2004.csv", "Data sets/NumberPlayers/2004-2005.csv", 
              "Data sets/NumberPlayers/2005-2006.csv", "Data sets/NumberPlayers/2006-2007.csv", 
              "Data sets/NumberPlayers/2007-2008.csv", "Data sets/NumberPlayers/2008-2009.csv", 
              "Data sets/NumberPlayers/2009-2010.csv", "Data sets/NumberPlayers/2010-2011.csv", 
              "Data sets/NumberPlayers/2011-2012.csv", "Data sets/NumberPlayers/2012-2013.csv", 
              "Data sets/NumberPlayers/2013-2014.csv", "Data sets/NumberPlayers/2014-2015.csv",
              "Data sets/NumberPlayers/2015-2016.csv", "Data sets/NumberPlayers/2016-2017.csv",
              "Data sets/NumberPlayers/2017-2018.csv", "Data sets/NumberPlayers/2018-2019.csv", 
              "Data sets/NumberPlayers/2019-2020.csv", "Data sets/NumberPlayers/2020-2021.csv", 
              "Data sets/NumberPlayers/2021-2022.csv", "Data sets/NumberPlayers/2022-2023.csv", 
              "Data sets/NumberPlayers/2023-2024.csv"]
players_df = load_and_filter_players_data(file_paths, filtered_teams)
players_df.reset_index(inplace=True)
players_df = players_df.rename(columns = {'Nation':'Country'})
players_df["Country"] = players_df["Country"].replace("Türkiye", "Turkey") #ensure country names are same for merging
players_df["Country"] = players_df["Country"].replace("Korea Republic", "South Korea")
players_df.to_csv("players_df.csv", index=False)
players_df
# Out:
#           Country   2003   2004   2005   2006   2007   2008   2009   2010  \
# 0       Argentina   98.0   71.0   80.0   85.0   85.0   91.0  103.0   98.0
# 1          Brazil  104.0  107.0  129.0  123.0  144.0  148.0  123.0  115.0
# 2        Colombia    6.0    8.0   10.0   10.0   13.0   12.0   17.0   18.0
# 3         England  191.0  200.0  197.0  193.0  173.0  189.0  182.0  192.0
# 4          France  365.0  330.0  329.0  311.0  325.0  335.0  310.0  315.0
# 5         Germany  226.0  214.0  231.0  223.0  212.0  202.0  204.0  214.0
# 6       Indonesia    NaN    NaN    NaN    NaN    NaN    NaN    1.0    1.0
# 7           Italy  318.0  374.0  382.0  388.0  351.0  352.0  330.0  295.0
# 8     South Korea    2.0    1.0    6.0    5.0    5.0    6.0    7.0    7.0
# 9          Mexico    3.0    2.0    4.0    5.0    9.0    9.0    9.0    7.0
# 10    Netherlands   35.0   31.0   37.0   37.0   29.0   34.0   30.0   34.0
# 11         Poland   12.0   17.0   16.0   18.0   19.0   16.0   16.0   18.0
# 12       Portugal   29.0   31.0   36.0   38.0   39.0   37.0   34.0   32.0
# 13          Qatar    1.0    NaN    NaN    NaN    1.0    1.0    NaN    NaN
# 14   Saudi Arabia    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 15       Scotland   28.0   20.0   21.0   21.0   16.0    8.0   22.0   21.0
# 16          Spain  361.0  398.0  368.0  337.0  351.0  351.0  365.0  366.0
# 17    Switzerland   15.0   20.0   27.0   25.0   26.0   27.0   27.0   26.0
# 18         Turkey   15.0   12.0   14.0    9.0   12.0   18.0   13.0   12.0
# 19  United States   11.0   14.0   11.0   20.0   17.0   13.0   17.0   18.0
#
#      2011  ...   2014   2015   2016   2017   2018   2019   2020   2021   2022  \
# 0   101.0  ...  110.0   96.0   98.0  102.0   89.0   78.0   83.0   74.0   82.0
# 1   107.0  ...  110.0  128.0  122.0  117.0  118.0  126.0  112.0  106.0  107.0
# 2    21.0  ...   25.0   25.0   23.0   24.0   24.0   23.0   22.0   23.0   27.0
# 3   195.0  ...  227.0  222.0  223.0  215.0  209.0  241.0  257.0  283.0  271.0
# 4   309.0  ...  346.0  383.0  369.0  343.0  368.0  357.0  410.0  416.0  423.0
# 5   223.0  ...  272.0  274.0  268.0  268.0  258.0  282.0  264.0  285.0  287.0
# 6     1.0  ...    1.0    1.0    2.0    1.0    2.0    1.0    NaN    NaN    NaN
# 7   297.0  ...  361.0  358.0  382.0  349.0  326.0  328.0  344.0  357.0  327.0
# 8     8.0  ...    9.0    9.0    7.0    9.0   10.0    9.0    9.0    8.0    6.0
# 9     9.0  ...    9.0    8.0    7.0    7.0   10.0    7.0    7.0   11.0    7.0
# 10   35.0  ...   33.0   41.0   41.0   50.0   48.0   56.0   70.0   78.0   67.0
# 11   17.0  ...   25.0   22.0   30.0   30.0   29.0   30.0   36.0   38.0   43.0
# 12   37.0  ...   44.0   45.0   50.0   45.0   54.0   58.0   69.0   61.0   76.0
# 13    NaN  ...    1.0    NaN    1.0    NaN    NaN    NaN    NaN    NaN    NaN
# 14    NaN  ...    NaN    NaN    NaN    2.0    NaN    NaN    NaN    NaN    NaN
# 15   21.0  ...   19.0   19.0   21.0   14.0   12.0   20.0   22.0   29.0   27.0
# 16  371.0  ...  415.0  419.0  408.0  413.0  416.0  475.0  520.0  535.0  498.0
# 17   25.0  ...   31.0   41.0   40.0   40.0   33.0   34.0   42.0   38.0   29.0
# 18   17.0  ...   15.0   16.0   17.0   17.0   21.0   19.0   23.0   21.0   19.0
# 19   19.0  ...   16.0   16.0   15.0   16.0   22.0   18.0   19.0   32.0   26.0
#
#      2023
# 0    75.0
# 1   107.0
# 2    27.0
# 3   304.0
# 4   383.0
# 5   295.0
# 6     1.0
# 7   320.0
# 8     8.0
# 9     9.0
# 10   62.0
# 11   37.0
# 12   71.0
# 13    NaN
# 14    NaN
# 15   25.0
# 16  496.0
# 17   36.0
# 18   16.0
# 19   27.0
#
# [20 rows x 22 columns]

# %%
#Step 3: Merging the first two datasets into one
fifa_ranking_df_long = fifa_ranking_df.melt(id_vars=["Country"], var_name="Year", value_name="FIFA Ranking")
players_df_long = players_df.melt(id_vars=["Country"], var_name="Year", value_name="Number of Players")


df = pd.merge(fifa_ranking_df_long, players_df_long, on=["Country", "Year"], how="outer")
df.to_csv("df.csv", index=False) #download the merged dataset to check if it has been merged properly
df
# Out:
#            Country  Year  FIFA Ranking  Number of Players
# 0        Argentina  2003           5.0               98.0
# 1        Argentina  2004           3.0               71.0
# 2        Argentina  2005           4.0               80.0
# 3        Argentina  2006           3.0               85.0
# 4        Argentina  2007           1.0               85.0
# ..             ...   ...           ...                ...
# 415  United States  2019          22.0               18.0
# 416  United States  2020          22.0               19.0
# 417  United States  2021          11.0               32.0
# 418  United States  2022          13.0               26.0
# 419  United States  2023           NaN               27.0
#
# [420 rows x 4 columns]

# %%
market_value = pd.read_csv("Data sets/Market Value/marketvalue.csv")
exchange_rate = 1.05 #Exchange rate EURO to USD
market_value["Average Market Value (in Million USD)"] = market_value["Average Market Value (in Million Euros)"] * exchange_rate
market_value["Total Market Value (in Million USD)"] = market_value["Total Market Value (in Million Euro)"] * exchange_rate
market_value = market_value.drop(columns = ["Average Market Value (in Million Euros)", "Total Market Value (in Million Euro)"])
market_value
# Out:
#        Country  Year  Average Market Value (in Million USD)  \
# 0    Argentina  2003                                    NaN
# 1    Argentina  2004                                    NaN
# 2    Argentina  2005                                    NaN
# 3    Argentina  2006                                    NaN
# 4    Argentina  2007                                    NaN
# ..         ...   ...                                    ...
# 415    England  2019                                11.2455
# 416    England  2020                                12.0225
# 417    England  2021                                12.1800
# 418    England  2022                                14.1435
# 419    England  2023                                15.0150
#
#      Total Market Value (in Million USD)
# 0                                    NaN
# 1                                    NaN
# 2                                    NaN
# 3                                    NaN
# 4                                    NaN
# ..                                   ...
# 415                               8715.0
# 416                               9618.0
# 417                               9807.0
# 418                               1188.6
# 419                               1283.1
#
# [420 rows x 4 columns]

# %%
#Step 3: Adding the next dataset
df["Year"] = df["Year"].astype(int)
market_value["Year"] = market_value["Year"].astype(int) 

# Merge the DataFrames
df = pd.merge(df, market_value[["Country", "Year", "Average Market Value (in Million USD)", "Total Market Value (in Million USD)"]],
    on=["Country", "Year"],
    how="outer")

df.to_csv("df.csv", index=False) #download to see if data was merged correctly
df
# Out:
#            Country  Year  FIFA Ranking  Number of Players  \
# 0        Argentina  2003           5.0               98.0
# 1        Argentina  2004           3.0               71.0
# 2        Argentina  2005           4.0               80.0
# 3        Argentina  2006           3.0               85.0
# 4        Argentina  2007           1.0               85.0
# ..             ...   ...           ...                ...
# 415  United States  2019          22.0               18.0
# 416  United States  2020          22.0               19.0
# 417  United States  2021          11.0               32.0
# 418  United States  2022          13.0               26.0
# 419  United States  2023           NaN               27.0
#
#      Average Market Value (in Million USD)  \
# 0                                      NaN
# 1                                      NaN
# 2                                      NaN
# 3                                      NaN
# 4                                      NaN
# ..                                     ...
# 415                                0.80745
# 416                                0.99750
# 417                                1.11300
# 418                                1.30200
# 419                                1.37550
#
#      Total Market Value (in Million USD)
# 0                                    NaN
# 1                                    NaN
# 2                                    NaN
# 3                                    NaN
# 4                                    NaN
# ..                                   ...
# 415                              652.869
# 416                              838.005
# 417                              916.545
# 418                             1186.500
# 419                             1365.000
#
# [420 rows x 6 columns]

# %% [markdown]
# **Economic Metrics**
#
# GDP and GNI over 2003 to 2023. Then we select only the 20 countries we are interested in.

# %%
# Loading GDP data (2010-2023)
filtered_teams = [
    "England", "Spain", "Germany", "Brazil", "Italy", "Argentina", "Mexico",
    "United States", "France", "Saudi Arabia", "Turkiye", "Qatar", "Korea, Rep.",
    "Indonesia", "Colombia", "Portugal", "Netherlands", "Poland", "Scotland",
    "Switzerland"
]
gdp = pd.read_csv("Data sets/GDP/GDP.csv", skiprows = 4)

cleaned_gdp = gdp.loc[:, ['Country Name'] + [str(year) for year in range(2003, 2024)]]


selected_gdp = cleaned_gdp[cleaned_gdp['Country Name'].isin(filtered_teams)] #missing data for England and Scotland

# add GDP data for England
england_gdp_data = {
    "Country Name": "England",
    "2003": 2054.42e9, "2004": 2421.53e9, "2005": 2543.18e9, "2006": 2708.44e9,
    "2007": 3090.51e9, "2008": 2929.41e9, "2009": 2412.84e9, "2010": 2485.48e9,
    "2011": 2663.81e9, "2012": 2707.09e9, "2013": 2784.85e9, "2014": 3064.71e9,
    "2015": 2927.91e9, "2016": 2689.11e9, "2017": 2680.15e9, "2018": 2871.34e9,
    "2019": 2851.41e9, "2020": 2697.81e9, "2021": 3141.51e9, "2022": 3088.84e9,
    "2023": 3340.03e9}

england_gdp_df = pd.DataFrame([england_gdp_data])
selected_gdp = pd.concat([selected_gdp, england_gdp_df], ignore_index=True)
selected_gdp = selected_gdp.rename(columns = {'Country Name':'Country'})

# add GDP data for Scotland 
scotland_gdp = pd.read_csv("Data sets/GDP/Scotland_GDP.csv")
scotland_gdp['GDP in GBP'] = scotland_gdp['GDP in million GBP'] * 1000000
exchange_rate = 1.26
scotland_gdp['GDP'] = scotland_gdp['GDP in GBP'] * exchange_rate
scotland_gdp = scotland_gdp.drop(columns = ['GDP in million GBP', 'GDP in GBP'])
scotland_gdp= scotland_gdp.pivot(
    index=['Country'], columns="Year", values="GDP").reset_index()

scotland_gdp.columns = scotland_gdp.columns.astype(str) #finally found issue after printing columns. Scotland columns were integers...

selected_gdp = pd.concat([selected_gdp, scotland_gdp], ignore_index=True)
selected_gdp["Country"] = selected_gdp["Country"].replace("Korea, Rep.", "South Korea")
selected_gdp["Country"] = selected_gdp["Country"].replace("Turkiye", "Turkey")
selected_gdp
selected_gdp.to_csv("gdp.csv", index=False)

# %%
#Step 3: Merging the df dataset and adding the GDP data

#First we need to get the GDP data ready. 

selected_gdp_long = selected_gdp.melt(id_vars=["Country"], var_name="Year", value_name="GDP")
df['Year'] = df['Year'].astype(str)

# Merge the GDP data with df on 'Country' and 'Year'
df = pd.merge(df, selected_gdp_long, on=["Country", "Year"], how="outer")
df
# Out:
#            Country  Year  FIFA Ranking  Number of Players  \
# 0        Argentina  2003           5.0               98.0
# 1        Argentina  2004           3.0               71.0
# 2        Argentina  2005           4.0               80.0
# 3        Argentina  2006           3.0               85.0
# 4        Argentina  2007           1.0               85.0
# ..             ...   ...           ...                ...
# 415  United States  2019          22.0               18.0
# 416  United States  2020          22.0               19.0
# 417  United States  2021          11.0               32.0
# 418  United States  2022          13.0               26.0
# 419  United States  2023           NaN               27.0
#
#      Average Market Value (in Million USD)  \
# 0                                      NaN
# 1                                      NaN
# 2                                      NaN
# 3                                      NaN
# 4                                      NaN
# ..                                     ...
# 415                                0.80745
# 416                                0.99750
# 417                                1.11300
# 418                                1.30200
# 419                                1.37550
#
#      Total Market Value (in Million USD)           GDP
# 0                                    NaN  1.275870e+11
# 1                                    NaN  1.646579e+11
# 2                                    NaN  1.987371e+11
# 3                                    NaN  2.325573e+11
# 4                                    NaN  2.875305e+11
# ..                                   ...           ...
# 415                              652.869  2.152140e+13
# 416                              838.005  2.132295e+13
# 417                              916.545  2.359403e+13
# 418                             1186.500  2.574411e+13
# 419                             1365.000  2.736094e+13
#
# [420 rows x 7 columns]

# %%
# Loading GNI data (2003-2023)
filtered_teams = [
    "England", "Spain", "Germany", "Brazil", "Italy", "Argentina", "Mexico",
    "United States", "France", "Saudi Arabia", "Turkiye", "Qatar", "Korea, Rep.",
    "Indonesia", "Colombia", "Portugal", "Netherlands", "Poland", "Scotland",
    "Switzerland"
]
gni = pd.read_csv("Data sets/GNIPerCapita/GNI Per Capita.csv", skiprows = 4)

cleaned_gni = gdp.loc[:, ['Country Name'] + [str(year) for year in range(2003, 2024)]]
selected_gni = cleaned_gni[cleaned_gni['Country Name'].isin(filtered_teams)]

# add GDP data for England
england_gni_data = {
    "Country Name": "United Kingdom",
    "2003": 1923.87e9, "2004": 2268.31e9, "2005": 2579.43e9, "2006": 2728.98e9,
    "2007": 2905.85e9, "2008": 2990.66e9, "2009": 2745.24e9, "2010": 2621.56e9,
    "2011": 2599.97e9, "2012": 2662.48e9, "2013": 2744.03e9, "2014": 2879.86e9,
    "2015": 2890.07e9, "2016": 2818.54e9, "2017": 2752.28e9, "2018": 2792.60e9,
    "2019": 2890.07e9, "2020": 2599.18e9, "2021": 3052.77e9, "2022": 3297.43e9,
    "2023": 3266.99e9}

england_gni_df = pd.DataFrame([england_gni_data])
selected_gni = pd.concat([selected_gni, england_gni_df], ignore_index=True)
selected_gni = selected_gni.rename(columns = {'Country Name':'Country'})

# add GDP data for Scotland 
scotland_gni = pd.read_csv("Data sets/GNIPerCapita/Scotland_GNI.csv")
scotland_gni['GNI in GBP'] = scotland_gni['GDP in million GBP'] * 1000000 #mistakenly used 'GDP' for column when gathering data
exchange_rate = 1.26
scotland_gni['GNI'] = scotland_gni['GNI in GBP'] * exchange_rate
scotland_gni = scotland_gni.drop(columns = ['GDP in million GBP', 'GNI in GBP'])
scotland_gni= scotland_gni.pivot(
    index=['Country'], columns="Year", values="GNI").reset_index()

scotland_gni.columns = scotland_gni.columns.astype(str)

selected_gni = pd.concat([selected_gni, scotland_gni], ignore_index=True)
selected_gni["Country"] = selected_gni["Country"].replace("Korea, Rep.", "South Korea")
selected_gni["Country"] = selected_gni["Country"].replace("Turkiye", "Turkey")
selected_gni["Country"] = selected_gni["Country"].replace("United Kingdom", "England")

selected_gni
# Out:
#           Country          2003          2004          2005          2006  \
# 0       Argentina  1.275870e+11  1.646579e+11  1.987371e+11  2.325573e+11
# 1          Brazil  5.582337e+11  6.692894e+11  8.916338e+11  1.107627e+12
# 2     Switzerland  3.620751e+11  4.039129e+11  4.182849e+11  4.416347e+11
# 3        Colombia  9.464497e+10  1.170924e+11  1.456005e+11  1.617930e+11
# 4         Germany  2.501640e+12  2.814354e+12  2.846864e+12  2.994704e+12
# 5           Spain  9.074915e+11  1.069056e+12  1.153716e+12  1.260399e+12
# 6          France  1.844545e+12  2.119633e+12  2.196945e+12  2.320536e+12
# 7       Indonesia  2.347725e+11  2.568369e+11  2.858686e+11  3.645705e+11
# 8           Italy  1.577622e+12  1.806543e+12  1.858217e+12  1.949552e+12
# 9     South Korea  7.027149e+11  7.931756e+11  9.349011e+11  1.053217e+12
# 10         Mexico  7.655500e+11  8.194592e+11  9.175719e+11  1.020265e+12
# 11    Netherlands  5.800704e+11  6.583801e+11  6.853482e+11  7.339553e+11
# 12         Poland  2.178287e+11  2.551073e+11  3.061459e+11  3.446267e+11
# 13       Portugal  1.652262e+11  1.893821e+11  1.972539e+11  2.087564e+11
# 14          Qatar  2.353379e+10  3.173407e+10  4.453049e+10  6.088214e+10
# 15   Saudi Arabia  2.158077e+11  2.587421e+11  3.284596e+11  3.769001e+11
# 16         Turkey  3.145956e+11  4.088654e+11  5.063147e+11  5.570762e+11
# 17  United States  1.145645e+13  1.221720e+13  1.303920e+13  1.381558e+13
# 18        England  1.923870e+12  2.268310e+12  2.579430e+12  2.728980e+12
# 19       Scotland  1.603645e+12  1.680238e+12  1.780714e+12  1.847489e+12
#
#             2007          2008          2009          2010          2011  ...  \
# 0   2.875305e+11  3.615580e+11  3.329765e+11  4.236274e+11  5.301581e+11  ...
# 1   1.397114e+12  1.695855e+12  1.666996e+12  2.208838e+12  2.616156e+12  ...
# 2   4.907407e+11  5.672678e+11  5.542129e+11  5.988510e+11  7.158881e+11  ...
# 3   2.062295e+11  2.425042e+11  2.324687e+11  2.864985e+11  3.349661e+11  ...
# 4   3.425578e+12  3.745264e+12  3.411261e+12  3.399668e+12  3.749315e+12  ...
# 5   1.474003e+12  1.631863e+12  1.491473e+12  1.422108e+12  1.480710e+12  ...
# 6   2.660591e+12  2.930304e+12  2.700887e+12  2.645188e+12  2.865158e+12  ...
# 7   4.322167e+11  5.102286e+11  5.395801e+11  7.550942e+11  8.929691e+11  ...
# 8   2.213102e+12  2.408655e+12  2.199929e+12  2.136100e+12  2.294994e+12  ...
# 9   1.172614e+12  1.047339e+12  9.439419e+11  1.143672e+12  1.253290e+12  ...
# 10  1.102356e+12  1.161553e+12  9.434374e+11  1.105424e+12  1.229014e+12  ...
# 11  8.485589e+11  9.518700e+11  8.715186e+11  8.473809e+11  9.052706e+11  ...
# 12  4.290208e+11  5.335998e+11  4.397316e+11  4.756966e+11  5.243742e+11  ...
# 13  2.404961e+11  2.634164e+11  2.446678e+11  2.381130e+11  2.451180e+11  ...
# 14  7.971209e+10  1.152701e+11  9.779835e+10  1.251223e+11  1.677753e+11  ...
# 15  4.159645e+11  5.197968e+11  4.290979e+11  5.282072e+11  6.766347e+11  ...
# 16  6.813211e+11  7.704491e+11  6.492893e+11  7.769673e+11  8.387853e+11  ...
# 17  1.447423e+13  1.476986e+13  1.447807e+13  1.504897e+13  1.559973e+13  ...
# 18  2.905850e+12  2.990660e+12  2.745240e+12  2.621560e+12  2.599970e+12  ...
# 19  1.928473e+12  1.981437e+12  1.935095e+12  2.027668e+12  2.103614e+12  ...
#
#             2014          2015          2016          2017          2018  \
# 0   5.263197e+11  5.947493e+11  5.575323e+11  6.436284e+11  5.248199e+11
# 1   2.456044e+12  1.802212e+12  1.795693e+12  2.063515e+12  1.916934e+12
# 2   7.265378e+11  6.941182e+11  6.878955e+11  6.952008e+11  7.255687e+11
# 3   3.812409e+11  2.934924e+11  2.827201e+11  3.118669e+11  3.341982e+11
# 4   3.889093e+12  3.357586e+12  3.469853e+12  3.690849e+12  3.974443e+12
# 5   1.371821e+12  1.196157e+12  1.233555e+12  1.313245e+12  1.421703e+12
# 6   2.855964e+12  2.439189e+12  2.472964e+12  2.595151e+12  2.790957e+12
# 7   8.908148e+11  8.608542e+11  9.318774e+11  1.015619e+12  1.042272e+12
# 8   2.162010e+12  1.836638e+12  1.877072e+12  1.961796e+12  2.091932e+12
# 9   1.484489e+12  1.466039e+12  1.499680e+12  1.623074e+12  1.725373e+12
# 10  1.364508e+12  1.213294e+12  1.112233e+12  1.190721e+12  1.256300e+12
# 11  8.921680e+11  7.655728e+11  7.840604e+11  8.338696e+11  9.140434e+11
# 12  5.390805e+11  4.771113e+11  4.700246e+11  5.246413e+11  5.887798e+11
# 13  2.299020e+11  1.993941e+11  2.064262e+11  2.213579e+11  2.423131e+11
# 14  2.062246e+11  1.617400e+11  1.517322e+11  1.610991e+11  1.833350e+11
# 15  7.666059e+11  6.694843e+11  6.660000e+11  7.149947e+11  8.465837e+11
# 16  9.389346e+11  8.643138e+11  8.696829e+11  8.589885e+11  7.789722e+11
# 17  1.760814e+13  1.829502e+13  1.880491e+13  1.961210e+13  2.065652e+13
# 18  2.879860e+12  2.890070e+12  2.818540e+12  2.752280e+12  2.792600e+12
# 19  2.304845e+12  2.362099e+12  2.450589e+12  2.595694e+12  2.675044e+12
#
#             2019          2020          2021          2022          2023
# 0   4.477547e+11  3.857405e+11  4.879026e+11  6.311334e+11  6.405914e+11
# 1   1.873288e+12  1.476107e+12  1.670647e+12  1.951924e+12  2.173666e+12
# 2   7.213691e+11  7.419994e+11  8.134088e+11  8.184266e+11  8.849404e+11
# 3   3.230317e+11  2.703483e+11  3.185246e+11  3.453299e+11  3.635402e+11
# 4   3.889178e+12  3.887727e+12  4.278504e+12  4.082469e+12  4.456081e+12
# 5   1.394320e+12  1.278129e+12  1.445652e+12  1.417800e+12  1.580695e+12
# 6   2.728870e+12  2.647419e+12  2.959356e+12  2.779092e+12  3.030904e+12
# 7   1.119100e+12  1.059055e+12  1.186510e+12  1.319076e+12  1.371171e+12
# 8   2.011302e+12  1.897462e+12  2.154875e+12  2.066972e+12  2.254851e+12
# 9   1.651423e+12  1.644313e+12  1.818432e+12  1.673917e+12  1.712793e+12
# 10  1.305211e+12  1.120832e+12  1.313070e+12  1.463324e+12  1.788887e+12
# 11  9.101943e+11  9.097935e+11  1.029678e+12  1.009399e+12  1.118125e+12
# 12  5.960585e+11  5.994427e+11  6.813461e+11  6.897633e+11  8.112291e+11
# 13  2.399869e+11  2.290319e+11  2.555348e+11  2.551967e+11  2.870800e+11
# 14  1.763713e+11  1.444114e+11  1.797320e+11  2.357704e+11           NaN
# 15  8.385648e+11  7.342712e+11  8.741560e+11  1.108571e+12  1.067583e+12
# 16  7.610059e+11  7.203385e+11  8.198653e+11  9.071184e+11  1.108022e+12
# 17  2.152140e+13  2.132295e+13  2.359403e+13  2.574411e+13  2.736094e+13
# 18  2.890070e+12  2.599180e+12  3.052770e+12  3.297430e+12  3.266990e+12
# 19  2.811900e+12  2.593739e+12  2.896804e+12  3.200700e+12  3.404184e+12
#
# [20 rows x 22 columns]

# %%
#Step 3: Finally, merging the df dataset and adding the GNI data

#First we need to get the GNI data ready. 
selected_gni_long = selected_gni.melt(id_vars=["Country"], var_name="Year", value_name="GNI")

final_df = pd.merge(df, selected_gni_long, on=["Country", "Year"], how="outer")
final_df.to_csv("final_df.csv", index=False)
final_df
# Out:
#            Country  Year  FIFA Ranking  Number of Players  \
# 0        Argentina  2003           5.0               98.0
# 1        Argentina  2004           3.0               71.0
# 2        Argentina  2005           4.0               80.0
# 3        Argentina  2006           3.0               85.0
# 4        Argentina  2007           1.0               85.0
# ..             ...   ...           ...                ...
# 415  United States  2019          22.0               18.0
# 416  United States  2020          22.0               19.0
# 417  United States  2021          11.0               32.0
# 418  United States  2022          13.0               26.0
# 419  United States  2023           NaN               27.0
#
#      Average Market Value (in Million USD)  \
# 0                                      NaN
# 1                                      NaN
# 2                                      NaN
# 3                                      NaN
# 4                                      NaN
# ..                                     ...
# 415                                0.80745
# 416                                0.99750
# 417                                1.11300
# 418                                1.30200
# 419                                1.37550
#
#      Total Market Value (in Million USD)           GDP           GNI
# 0                                    NaN  1.275870e+11  1.275870e+11
# 1                                    NaN  1.646579e+11  1.646579e+11
# 2                                    NaN  1.987371e+11  1.987371e+11
# 3                                    NaN  2.325573e+11  2.325573e+11
# 4                                    NaN  2.875305e+11  2.875305e+11
# ..                                   ...           ...           ...
# 415                              652.869  2.152140e+13  2.152140e+13
# 416                              838.005  2.132295e+13  2.132295e+13
# 417                              916.545  2.359403e+13  2.359403e+13
# 418                             1186.500  2.574411e+13  2.574411e+13
# 419                             1365.000  2.736094e+13  2.736094e+13
#
# [420 rows x 8 columns]

# %% [markdown]
# ## Step 4: Predictive Analysis
#
# Now that we have created a dataset, we split it into training and testing sets to see if we can predict GDP and GDNI using predictive analysis.
#
# First we train a linear regression model with the data after dropping all rows with missing values. We will split 80% of the data for the training set and 20% for the testing set. We will then use the mean squared error and the r squared metrics to evaluate the model.

# %% [markdown]
# ***Linear Regression to Predict GDP***

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score
import matplotlib.pyplot as plt

final_df = pd.read_csv("final_df.csv")

#Dropping rows with missing values
cleaned_df = final_df.dropna()

#Setting features and target variables
features = ['FIFA Ranking', 'Number of Players', 'Average Market Value (in Million USD)', 
            'Total Market Value (in Million USD)']
target = 'GDP'

X = cleaned_df[features]
y = cleaned_df[target]

X_train, X_test, y_train, y_test = train_test_split(X, y, train_size=0.8, random_state=707)

model = LinearRegression()
model.fit(X_train, y_train)

y_pred = model.predict(X_test)

#Evaluating the model
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

print(f"Mean Squared Error: {mse:.4f}")
print(f"R-squared: {r2:.4f}")

#Plot
plt.figure(figsize=(10, 6))
plt.scatter(y_test, y_pred, alpha=0.7, label="Predicted vs Actual")
plt.plot([y_test.min(), y_test.max()], [y_test.min(), y_test.max()], 'r--', lw=2, label="Ideal Fit")
plt.xlabel("Actual GDP")
plt.ylabel("Predicted GDP")
plt.title("Linear Regression: Actual vs Predicted GDP")
plt.legend()
plt.grid()
plt.show()
# Out:
# Mean Squared Error: 17204734831550417615192064.0000
# R-squared: -0.3272

# %% [markdown]
# The mean squared error value and the r squared values indicate that the data we have found do not do well to predict GDP at all. We will try training a decision tree to see if we can capture more of the variance, and then a regression forest.

# %% [markdown]
# ***Decision Tree Algorithm to Predict GDP***

# %%
# Predict GDP using the trained Decision Tree
from sklearn.tree import DecisionTreeRegressor

decision_tree_model = DecisionTreeRegressor(random_state=707)
decision_tree_model.fit(X_train, y_train)

y_pred_tree = decision_tree_model.predict(X_test)

mse_tree = mean_squared_error(y_test, y_pred_tree)
r2_tree = r2_score(y_test, y_pred_tree)

print(f"Mean Squared Error: {mse_tree:.4f}")
print(f"R-squared: {r2_tree:.4f}")

#Plot
plt.figure(figsize=(10, 6))
plt.scatter(y_test, y_pred_tree, alpha=0.7, label="Predicted vs Actual GDP (Decision Tree)")
plt.plot([y_test.min(), y_test.max()], [y_test.min(), y_test.max()], 'r--', lw=2, label="Ideal Fit")
plt.xlabel("Actual GDP")
plt.ylabel("Predicted GDP")
plt.title("Decision Tree: Actual vs Predicted GNI")
plt.legend()
plt.grid()
plt.show()
# Out:
# Mean Squared Error: 11270031358198374163546112.0000
# R-squared: 0.1306

# %% [markdown]
# We found the a decision tree does better to capture more of the variance in GDP indicated by an r squared value of 0.1306. This indicates that footballing metrics we have found may account for about 13.06% of the variance in GDP. We now feed our data to a random forest algorithm.

# %% [markdown]
# ***Random Forest Algorithm to Predict GDP***

# %%
# Predict GDP using the trained Random Forest model
from sklearn.ensemble import RandomForestRegressor

random_forest_model = RandomForestRegressor(random_state=707, n_estimators=100)
random_forest_model.fit(X_train, y_train)

y_pred_rf = random_forest_model.predict(X_test)

mse_rf = mean_squared_error(y_test, y_pred_rf)
r2_rf = r2_score(y_test, y_pred_rf)

print(f"Mean Squared Error: {mse_rf:.4f}")
print(f"R-squared: {r2_rf:.4f}")

#Finding Feature Importance for the trained Random Forest model
feature_importances = random_forest_model.feature_importances_
importance_df = pd.DataFrame({
    'Feature': X_train.columns,
    'Importance': feature_importances
}).sort_values(by='Importance', ascending=False)

print(importance_df)

#Visualizing feature importances

plt.figure(figsize=(10, 6))
plt.bar(importance_df['Feature'], importance_df['Importance'], alpha=0.8)
plt.title("Feature Importance from Random Forest")
plt.xlabel("Features")
plt.ylabel("Importance Score")
plt.tight_layout()
plt.show()
# Out:
# Mean Squared Error: 6055674839022563238084608.0000
# R-squared: 0.5329
#                                  Feature  Importance
# 1                      Number of Players    0.326770
# 3    Total Market Value (in Million USD)    0.268796
# 0                           FIFA Ranking    0.212489
# 2  Average Market Value (in Million USD)    0.191945

# %% [markdown]
# A random forest model was significantly better at predicting GDP being able to explain about 53.3% of the variance in GDP. While this is an improvement, we still have 46.75% of the variance that require more data to explain.
#
# To gain some insight into what kind of data we need, we extract the feature importance scores given by the random forest algorithm.
#
# The importance scores illustrate that the most important feature was the 'number of players'. 'Number of players' was used in about 33% of decisions in the random forest algorithm.
#
# This feature represents the number of players from each country playing in the top 5 European leagues. This feature likely indicates the level of footballing infrastructure, i.e. the higher number means that the country possesses infrastracture capable of producing talents good enought to play in the top European leagues.
#
# Hence, we believe that more data on footballing infrastructure will help boost the model's predictive power. We also believe creating interaction terms between 'number of players' and 'total market value' may help uncover new relationships.
#
#
# ***Linear Regression to predict GNI***

# %%
cleaned_df = final_df.dropna()

features = ['FIFA Ranking', 'Number of Players', 'Average Market Value (in Million USD)', 
            'Total Market Value (in Million USD)']
target = 'GNI'

X = cleaned_df[features]
y = cleaned_df[target]

X_train, X_test, y_train, y_test = train_test_split(X, y, train_size=0.8, random_state=707)

model = LinearRegression()
model.fit(X_train, y_train)

y_pred = model.predict(X_test)

mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

print(f"Mean Squared Error: {mse:.4f}")
print(f"R-squared: {r2:.4f}")

#plotplt.figure(figsize=(10, 6))
plt.scatter(y_test, y_pred, alpha=0.7, label="Predicted vs Actual GNI")
plt.plot([y_test.min(), y_test.max()], [y_test.min(), y_test.max()], 'r--', lw=2, label="Ideal Fit")
plt.xlabel("Actual GNI")
plt.ylabel("Predicted GNI")
plt.title("Linear Regression: Actual vs Predicted GNI")
plt.legend()
plt.grid()
plt.show()
# Out:
# Mean Squared Error: 17235524114250321180491776.0000
# R-squared: -0.3298

# %%
decision_tree_model_gni = DecisionTreeRegressor(random_state=707)
decision_tree_model_gni.fit(X_train, y_train)

y_pred_tree_gni = decision_tree_model_gni.predict(X_test)

mse_tree_gni = mean_squared_error(y_test, y_pred_tree_gni)
r2_tree_gni = r2_score(y_test, y_pred_tree_gni)

print(f"Mean Squared Error: {mse_tree_gni:.4f}")
print(f"R-squared: {r2_tree_gni:.4f}")

plt.figure(figsize=(10, 6))
plt.scatter(y_test, y_pred_tree_gni, alpha=0.7, label="Predicted vs Actual GNI (Decision Tree)")
plt.plot([y_test.min(), y_test.max()], [y_test.min(), y_test.max()], 'r--', lw=2, label="Ideal Fit")
plt.xlabel("Actual GNI")
plt.ylabel("Predicted GNI")
plt.title("Decision Tree: Actual vs Predicted GNI")
plt.legend()
plt.grid()
plt.show()
# Out:
# Mean Squared Error: 11221193083216886287564800.0000
# R-squared: 0.1342

# %%
random_forest_model_gni = RandomForestRegressor(random_state=707, n_estimators=100)
random_forest_model_gni.fit(X_train, y_train)

y_pred_rf_gni = random_forest_model_gni.predict(X_test)

mse_rf_gni = mean_squared_error(y_test, y_pred_rf_gni)
r2_rf_gni = r2_score(y_test, y_pred_rf_gni)

print(f"Mean Squared Error: {mse_rf_gni:.4f}")
print(f"R-squared: {r2_rf_gni:.4f}")

feature_importances_gni = random_forest_model_gni.feature_importances_
importance_df_gni = pd.DataFrame({
    'Feature': X_train.columns,
    'Importance': feature_importances_gni
}).sort_values(by='Importance', ascending=False)

print(importance_df_gni)

#Plot
plt.figure(figsize=(10, 6))
plt.bar(importance_df_gni['Feature'], importance_df_gni['Importance'], alpha=0.8)
plt.title("Feature Importance from Random Forest (Target: GNI)")
plt.xlabel("Features")
plt.ylabel("Importance Score")
plt.show()
# Out:
# Mean Squared Error: 6031601856123169245495296.0000
# R-squared: 0.5346
#                                  Feature  Importance
# 1                      Number of Players    0.322913
# 3    Total Market Value (in Million USD)    0.267321
# 0                           FIFA Ranking    0.217962
# 2  Average Market Value (in Million USD)    0.191805
